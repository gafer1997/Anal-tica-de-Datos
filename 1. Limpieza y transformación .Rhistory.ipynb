# %% [markdown]
# # Instalar las librerías necesarias
#
# # Instalar las librerías necesarias
#
# install.packages(“rvest”) install.packages(“dplyr”)
# install.packages(“stringr”) install.packages(“tidyverse”) \# Instalar
# las librerías necesarias install.packages(“rvest”)
# install.packages(“dplyr”) \# Instalar las librerías necesarias
# install.packages(“rvest”) install.packages(“dplyr”)
# install.packages(“stringr”) install.packages(“tidyverse”) \# Cargar las
# librerías library(rvest) library(dplyr) library(stringr)
# library(tidyverse) \# Leer la página web url \<-
# ‘https://en.wikipedia.org/wiki/R\_(programming_language)’ webpage \<-
# read_html(url) url \<-
# ‘https://en.wikipedia.org/wiki/R\_(programming_language)’ webpage \<-
# read_html(url) first_paragraph \<- webpage %\>% html_node(‘p’) %\>%
# html_text() \# Mostrar el primer párrafo print(first_paragraph) \#
# Extraer la tabla de información (infobox) infobox \<- webpage %\>%
# html_node(‘.infobox’) %\>% html_table() \# Mostrar la tabla de
# información print(infobox) \# Limpiar el primer párrafo
# first_paragraph_clean \<- str_trim(first_paragraph) \# Mostrar el
# párrafo limpio print(first_paragraph_clean) \# Limpiar y estructurar la
# tabla de información infobox_clean \<- infobox %\>% rename(Attribute =
# 1, Value = 2) %\>% filter(!is.na(Attribute)) \# Mostrar la tabla de
# información limpia print(infobox_clean) \# Agregar una columna ficticia
# de datos numéricos para el análisis set.seed(123) \# Para
# reproducibilidad
# infobox_clean$NumericValue <- sample(1:100, nrow(infobox_clean), replace = TRUE) # Mostrar la tabla con la nueva columna print(infobox_clean) # Calcular medidas de resumen estadístico summary_stats <- infobox_clean %>% summarise( Mean = mean(NumericValue), Median = median(NumericValue), SD = sd(NumericValue), Min = min(NumericValue), Max = max(NumericValue) ) # Mostrar las medidas de resumen estadístico print(summary_stats) # Guardar el primer párrafo en un archivo de texto writeLines(first_paragraph_clean, 'primer_parrafo.txt') # Guardar la tabla de información en un archivo CSV write.csv(infobox_clean, 'infobox_R.csv', row.names = FALSE) # Guardar las medidas de resumen estadístico en un archivo CSV write.csv(summary_stats, 'summary_stats.csv', row.names = FALSE) # Leer la página web url <- 'https://es.wikipedia.org/wiki/Francisco_Marroqu%C3%ADn https://es.wikipedia.org/wiki/Francisco_Marroqu%C3%ADn # Leer la página web url <- 'https://es.wikipedia.org/wiki/Francisco_Marroqu%C3%ADn)' # Leer la página web url <- 'https://es.wikipedia.org/wiki/Francisco_Marroqu%C3%ADn)' webpage <- read_html(url) # Leer la página web url <- 'https://es.wikipedia.org/wiki/Francisco_Marroquin)' webpage <- read_html(url) # Instalar las librerías necesarias install.packages("rvest") install.packages("dplyr") install.packages("stringr") install.packages("tidyverse") # Instalar las librerías necesarias install.packages("rvest") install.packages("dplyr") install.packages("stringr") install.packages("tidyverse") install.packages("stringr") install.packages("dplyr") # Cargar las librerías library(rvest) library(dplyr) library(stringr) library(tidyverse) # Leer la página web url <- 'https://es.wikipedia.org/wiki/Francisco_Marroquin)' webpage <- read_html(url) # Leer la página web url <- 'https://es.wikipedia.org/wiki/Guatemala_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020)' webpage <- read_html(url) url <- 'https://es.wikipedia.org/wiki/Colores_pol%C3%ADticos)' webpage <- read_html(url) # Extraer el primer párrafo first_paragraph <- webpage %>% html_node('div') %>% html_text() url <- 'https://es.wikipedia.org/wiki/Colores_pol%C3%ADticos' webpage <- read_html(url # Extraer el primer párrafo first_paragraph <- webpage %>% url <- 'https://es.wikipedia.org/wiki/Colores_pol%C3%ADticos' webpage <- read_html(url) # Extraer el primer párrafo first_paragraph <- webpage %>% html_node('div') %>% html_text() # Mostrar el primer párrafo print(first_paragraph) # Extraer la tabla de información (infobox) infobox <- webpage %>% html_node('.infobox') %>% html_table() # Limpiar el primer párrafo first_paragraph_clean <- str_trim(first_paragraph) # Mostrar el párrafo limpio print(first_paragraph_clean) # Limpiar y estructurar la tabla de información infobox_clean <- infobox %>% rename(Attribute = 1, Value = 2) %>% filter(!is.na(Attribute)) # Agregar una columna ficticia de datos numéricos para el análisis set.seed(123) # Para reproducibilidad infobox_clean$NumericValue
# \<- sample(1:100, nrow(infobox_clean), replace = TRUE) url \<-
# ‘https://es.wikipedia.org/wiki/Ucrania_en_el_Festival_de_la_Canci%C3%B3n_de_Eurovisi%C3%B3n_2024’
# webpage \<- read_html(url) \# Leer la página web url \<-
# ‘https://es.wikipedia.org/wiki/Guatemala_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020’
# webpage \<- read_html(url) \# Extraer el primer párrafo first_paragraph
# \<- webpage %\>% html_node(‘p’) %\>% html_text() \# Mostrar el primer
# párrafo print(first_paragraph) \# Extraer la tabla de información
# (infobox) infobox \<- webpage %\>% html_node(‘.infobox’) %\>%
# html_table() \# Mostrar la tabla de información print(infobox) \#
# Limpiar el primer párrafo first_paragraph_clean \<-
# str_trim(first_paragraph) \# Mostrar el párrafo limpio
# print(first_paragraph_clean) \# Limpiar y estructurar la tabla de
# información infobox_clean \<- infobox %\>% rename(Attribute = 1, Value =
# 2) %\>% filter(!is.na(Attribute)) \# Mostrar la tabla de información
# limpia print(infobox_clean) \# Agregar una columna ficticia de datos
# numéricos para el análisis set.seed(123) \# Para reproducibilidad
# infobox_clean$NumericValue <- sample(1:100, nrow(infobox_clean), replace = TRUE) # Mostrar la tabla con la nueva columna print(infobox_clean) # Calcular medidas de resumen estadístico summary_stats <- infobox_clean %>% summarise( Mean = mean(NumericValue), Median = median(NumericValue), SD = sd(NumericValue), Min = min(NumericValue), Max = max(NumericValue) ) # Mostrar las medidas de resumen estadístico print(summary_stats) # Guardar el primer párrafo en un archivo de texto writeLines(first_paragraph_clean, 'primer_parrafo.txt') # Guardar la tabla de información en un archivo CSV write.csv(infobox_clean, 'infobox_R.csv', row.names = FALSE) # Guardar las medidas de resumen estadístico en un archivo CSV write.csv(summary_stats, 'summary_stats.csv', row.names = FALSE) getw(); getwd(); parrafos <- webpage %>% html_nodes('p') %>% html_text() segundo <- parrafos[2] segundo <- parrafos[3] segundo <- parrafos[4] print(segundo) writeLines(segundo, 'segundo_parrafo.txt') getwd(); segundo <- parrafos[3] print (segundo) library(readxl) myData <- read_excel("C:/Users/Telmy/Downloads/myData.xlsx") View(myData) datos <- read.csv("myData", header = TRUE) datos <- read.csv("datos.csv", header = TRUE) summary(datos) library(readxl) myData <- read_excel("C:/Users/Telmy/Downloads/myData.xlsx") View(myData) summary(datos) summary(myData) datos_sin_na <- na.omit(myData) myData_limpio <- myData_sin_na[, c("columna1", "columna2", "columna3")] datos_limpio <- myData_sin_na[, c("columna1", "columna2", "columna3")] myData_limpio <- datos_sin_na[, c("columna1", "columna2", "columna3")] myData_limpio$columna_numerica
# \<-
# as.numeric(datos_limpio$columna_numerica) library(readxl) myData <- read_excel("C:/Users/Telmy/Downloads/myData.xlsx") View(myData) summary(myData) myData_sin_na <- na.omit(myData) myData_limpio <- myData_sin_na[, c("columna1", "columna2", "columna3")] myData_filtrados <- myData_limpio[myData_limpio$columna1
# \> 10 &
# myData_limpio$columna2 < 5, ] write.csv(myData_filtrados, file = "myData_limpios.csv", row.names = FALSE) # Limpiar y estructurar la tabla de información infobox_clean <- infobox %>% rename(Attribute = 1, Value = 2) %>% filter(!is.na(Attribute)) # Limpiar y estructurar la tabla de información infobox_clean <- %>% # Instalar las librerías necesarias install.packages("rvest") install.packages("dplyr") install.packages("stringr") install.packages("tidyverse") # Leer la página web url <- 'https://en.wikipedia.org/wiki/R_(programming_language)' webpage <- read_html(url) # Cargar las librerías library(rvest) library(dplyr) library(stringr) library(tidyverse) # Leer la página web url <- 'https://es.wikipedia.org/wiki/Econom%C3%ADa_de_Guatemala' webpage <- read_html(url) # Limpiar el primer párrafo first_paragraph_clean <- str_trim(first_paragraph) # Limpiar el primer párrafo first_paragraph_clean <- str_trim(first_paragraph) # Extraer el primer párrafo first_paragraph <- webpage %>% html_node('p') %>% html_text() # Mostrar el primer párrafo print(first_paragraph) # Extraer la tabla de información (infobox) infobox <- webpage %>% html_node('.infobox') %>% html_table() # Mostrar la tabla de información print(infobox) # Limpiar el primer párrafo first_paragraph_clean <- str_trim(first_paragraph) # Mostrar el párrafo limpio print(first_paragraph_clean) # Limpiar y estructurar la tabla de información infobox_clean <- infobox %>% rename(Attribute = 1, Value = 2) %>% filter(!is.na(Attribute)) # Mostrar la tabla de información limpia print(infobox_clean) # Agregar una columna ficticia de datos numéricos para el análisis set.seed(123) # Para reproducibilidad infobox_clean$NumericValue
# \<- sample(1:100, nrow(infobox_clean), replace = TRUE) \# Mostrar la
# tabla con la nueva columna print(infobox_clean)
# savehistory(“C:/Users/Telmy/Downloads/Limpieza y transformación Telma
# Mijangos.Rhistory”)
